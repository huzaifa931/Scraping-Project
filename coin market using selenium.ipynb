# %%
pip install selenium
# Out:
# Requirement already satisfied: selenium in d:\new folder\lib\site-packages (4.32.0)
# Requirement already satisfied: urllib3<3,>=1.26 in d:\new folder\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.2.3)
# Requirement already satisfied: trio~=0.17 in d:\new folder\lib\site-packages (from selenium) (0.30.0)
# Requirement already satisfied: trio-websocket~=0.9 in d:\new folder\lib\site-packages (from selenium) (0.12.2)
# Requirement already satisfied: certifi>=2021.10.8 in d:\new folder\lib\site-packages (from selenium) (2024.8.30)
# Requirement already satisfied: typing_extensions~=4.9 in d:\new folder\lib\site-packages (from selenium) (4.11.0)
# Requirement already satisfied: websocket-client~=1.8 in d:\new folder\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in d:\new folder\lib\site-packages (from trio~=0.17->selenium) (25.3.0)
# Requirement already satisfied: sortedcontainers in d:\new folder\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in d:\new folder\lib\site-packages (from trio~=0.17->selenium) (3.7)
# Requirement already satisfied: outcome in d:\new folder\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in d:\new folder\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in d:\new folder\lib\site-packages (from trio~=0.17->selenium) (1.17.1)
# Requirement already satisfied: wsproto>=0.14 in d:\new folder\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in d:\new folder\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in d:\new folder\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in d:\new folder\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
                                            # importing
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import time

# %%
# Setup WebDriver
options = Options()
options.add_argument("--start-maximized")  
options.add_argument("--disable-gpu")
options.add_argument("--no-sandbox")
driver = webdriver.Chrome(options=options)

# %%
url = 'https://coinmarketcap.com/'
driver.get(url)
time.sleep(3)

# %%
# Slowly scroll to the bottom of the page
scroll_pause_time = 0.5
scroll_step = 300  # pixels per scroll
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    for i in range(0, last_height, scroll_step):
        driver.execute_script(f"window.scrollTo(0, {i});")
        time.sleep(scroll_pause_time)
    
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break  
    last_height = new_height

print("✅ Finished scrolling")

soup = BeautifulSoup(driver.page_source, "html.parser")
driver.quit()

table = soup.find('table', {'class': 'cmc-table'})

rows = table.find_all('tr')
print(f"✅ Found {len(rows)-1} rows (excluding header)")

crypto_data = []

for row in rows[1:]: 
    cols = row.find_all('td')
    if len(cols) >= 10:
        rank = cols[1].text.strip()
        name = cols[2].text.strip()
        price = cols[3].text.strip()
        one_hour_change = cols[4].text.strip()
        twenty_four_hour_change = cols[5].text.strip()
        seven_day_change = cols[6].text.strip()
        market_cap = cols[7].text.strip()
        hr_volume = cols[8].text.strip()
        circulating_supply = cols[9].text.strip()

        crypto_data.append([
            rank, name, price, one_hour_change,
            twenty_four_hour_change, seven_day_change,
            market_cap, hr_volume, circulating_supply
        ])

for coin in crypto_data:
    print(coin)
# Out:
# ✅ Finished scrolling
# ✅ Found 100 rows (excluding header)
# ['1', 'BitcoinBTCBuy', '$104,731.25', '0.48%', '2.78%', '10.26%', '$2.08T$2,080,413,001,894', '$52,191,516,789497.84K BTC', '19.86M BTC']
# ['2', 'EthereumETHBuy', '$2,692.99', '3.25%', '9.50%', '50.78%', '$325.12B$325,122,775,966', '$27,716,316,46410.23M ETH', '120.72M ETH']
# ['3', 'XRPXRPBuy', '$2.58', '0.91%', '3.35%', '20.84%', '$151.41B$151,412,951,970', '$6,349,319,4582.44B XRP', '58.55B XRP']
# ['4', 'TetherUSDTBuy', '$1.00', '0.02%', '0.03%', '0.03%', '$150.12B$150,117,725,431', '$100,240,268,449100.21B USDT', '150.05B USDT']
# ['5', 'SolanaSOLBuy', '$183.15', '2.52%', '7.04%', '26.37%', '$95.14B$95,138,612,868', '$4,690,189,98225.72M SOL', '519.44M SOL']
# ['6', 'BNBBNBBuy', '$669.73', '0.82%', '1.85%', '11.50%', '$94.36B$94,358,236,199', '$2,079,722,7513.10M BNB', '140.88M BNB']
# ['7', 'USDCUSDCBuy', '$1.00', '0.01%', '0.02%', '0.00%', '$60.87B$60,871,986,812', '$11,731,277,95411.73B USDC', '60.86B USDC']
# ['8', 'DogecoinDOGEBuy', '$0.2408', '1.44%', '6.19%', '42.44%', '$35.95B$35,947,686,318', '$2,698,983,81211.19B DOGE', '149.24B DOGE']
# ['9', 'CardanoADABuy', '$0.8373', '1.89%', '4.24%', '26.07%', '$29.57B$29,569,133,050', '$1,282,201,3361.53B ADA', '35.31B ADA']
# ['10', 'TRONTRXBuy', '$0.2725', '0.72%', '0.25%', '11.02%', '$25.86B$25,864,884,321', '$1,065,103,3423.90B TRX', '94.9B TRX']
# ['11', 'SuiSUIBuy', '$4.08', '1.65%', '4.58%', '25.99%', '$13.65B$13,648,426,990', '$1,471,566,570361.57M SUI', '3.33B SUI']
# ['12', 'ChainlinkLINKBuy', '$17.70', '2.40%', '7.56%', '29.69%', '$11.63B$11,631,769,929', '$594,482,72133.71M LINK', '657.09M LINK']
# ['13', 'AvalancheAVAXBuy', '$26.02', '2.74%', '6.65%', '30.71%', '$10.89B$10,891,129,838', '$474,727,29418.34M AVAX', '418.51M AVAX']
# ['14', 'StellarXLMBuy', '$0.3170', '1.26%', '2.74%', '22.45%', '$9.85B$9,849,401,097', '$327,996,3921.03B XLM', '31.06B XLM']
# ['15', 'Shiba InuSHIBBuy', '$0.00001648', '1.72%', '7.08%', '31.23%', '$9.72B$9,716,398,234', '$523,425,85931.68T SHIB', '589.24T SHIB']
# ['16', 'HederaHBARBuy', '$0.2176', '1.05%', '2.65%', '24.14%', '$9.19B$9,191,448,120', '$341,393,8631.57B HBAR', '42.23B HBAR']
# ['17', 'HyperliquidHYPEBuy', '$26.33', '0.87%', '9.54%', '27.51%', '$8.79B$8,793,133,075', '$166,405,0976.33M HYPE', '333.92M HYPE']
# ['18', 'ToncoinTONBuy', '$3.42', '1.49%', '3.28%', '13.01%', '$8.53B$8,526,181,111', '$208,252,69760.99M TON', '2.49B TON']
# ['19', 'PiPIBuy', '$1.18', '0.96%', '7.43%', '105.26%', '$8.45B$8,445,314,396', '$804,381,742677.41M PI', '7.09B PI']
# ['20', 'PolkadotDOTBuy', '$5.26', '2.15%', '4.55%', '33.55%', '$8.3B$8,296,131,539', '$275,754,25952.68M DOT', '1.57B DOT']
# ['21', 'Bitcoin CashBCHBuy', '$414.90', '1.32%', '1.86%', '15.01%', '$8.24B$8,243,887,811', '$278,898,051673.07K BCH', '19.86M BCH']
# ['22', 'UNUS SED LEOLEOBuy', '$8.70', '0.16%', '2.50%', '0.04%', '$8.04B$8,042,390,499', '$6,588,071756.64K LEO', '923.46M LEO']
# ['23', 'LitecoinLTCBuy', '$104.39', '1.78%', '3.33%', '23.52%', '$7.92B$7,918,190,612', '$760,566,9417.29M LTC', '75.85M LTC']
# ['24', 'MoneroXMRBuy', '$341.79', '0.20%', '1.70%', '20.49%', '$6.31B$6,305,028,018', '$144,609,041423.52K XMR', '18.44M XMR']
# ['25', 'PepePEPEBuy', '$0.00001496', '2.11%', '12.30%', '89.27%', '$6.29B$6,293,599,895', '$2,023,678,448135.44T PEPE', '420.68T PEPE']
# ['26', 'Bitget TokenBGBBuy', '$4.83', '0.58%', '1.85%', '13.50%', '$5.66B$5,659,753,147', '$254,633,70752.80M BGB', '1.16B BGB']
# ['27', 'DaiDAIBuy', '$1.00', '0.00%', '0.01%', '0.01%', '$5.37B$5,366,196,233', '$17,613,438,81917.61B DAI', '5.36B DAI']
# ['28', 'Ethena USDeUSDeBuy', '$1.00', '0.01%', '0.00%', '0.05%', '$4.75B$4,749,507,371', '$104,909,099104.79M USDe', '4.74B USDe']
# ['29', 'UniswapUNIBuy', '$7.29', '3.14%', '6.85%', '48.75%', '$4.59B$4,585,707,308', '$271,301,87737.47M UNI', '628.68M UNI']
# ['30', 'BittensorTAOBuy', '$467.44', '1.79%', '3.05%', '28.18%', '$4.11B$4,107,126,757', '$173,934,226371.32K TAO', '8.78M TAO']
# ['31', 'NEAR ProtocolNEARBuy', '$3.27', '2.24%', '5.18%', '42.49%', '$3.96B$3,964,949,523', '$224,070,63468.50M NEAR', '1.21B NEAR']
# ['32', 'AptosAPTBuy', '$6.21', '1.07%', '7.23%', '31.49%', '$3.92B$3,924,762,755', '$212,832,00734.34M APT', '631.92M APT']
# ['33', 'AaveAAVEBuy', '$237.05', '3.42%', '8.74%', '37.02%', '$3.58B$3,583,076,940', '$350,169,5461.48M AAVE', '15.11M AAVE']
# ['34', 'OndoONDOBuy', '$1.06', '3.25%', '5.79%', '25.20%', '$3.38B$3,376,502,868', '$270,410,080253.74M ONDO', '3.15B ONDO']
# ['35', 'KaspaKASBuy', '$0.1267', '1.78%', '15.75%', '38.62%', '$3.32B$3,316,718,623', '$209,484,5571.66B KAS', '26.16B KAS']
# ['36', 'OKBOKBBuy', '$54.08', '0.17%', '0.63%', '6.73%', '$3.25B$3,245,363,109', '$7,197,733132.94K OKB', '60M OKB']
# ['37', 'Internet ComputerICPBuy', '$5.92', '1.17%', '4.64%', '29.10%', '$3.16B$3,158,081,698', '$91,107,17715.34M ICP', '532.82M ICP']
# ['38', 'Ethereum ClassicETCBuy', '$20.87', '2.26%', '6.27%', '31.22%', '$3.17B$3,171,608,825', '$143,772,6906.92M ETC', '151.89M ETC']
# ['39', 'RenderRENDERBuy', '$5.40', '1.89%', '7.47%', '26.95%', '$2.8B$2,796,141,040', '$102,268,21718.92M RENDER', '517.71M RENDER']
# ['40', 'VeChainVETBuy', '$0.03234', '2.17%', '6.30%', '31.74%', '$2.78B$2,781,391,830', '$74,285,6162.31B VET', '85.98B VET']
# ['41', 'MantleMNTBuy', '$0.8236', '0.48%', '4.12%', '15.99%', '$2.77B$2,771,346,472', '$274,580,439334.52M MNT', '3.36B MNT']
# ['42', 'CronosCROBuy', '$0.1034', '1.08%', '3.52%', '19.41%', '$2.75B$2,749,769,581', '$45,423,297440.51M CRO', '26.57B CRO']
# ['43', 'POL (prev. MATIC)POLBuy', '$0.2636', '2.16%', '4.17%', '22.86%', '$2.75B$2,746,755,547', '$155,906,868592.75M POL', '10.42B POL']
# ['44', 'OFFICIAL TRUMPTRUMPBuy', '$13.66', '1.62%', '8.38%', '25.37%', '$2.73B$2,733,670,086', '$1,455,055,025106.47M TRUMP', '199.99M TRUMP']
# ['45', 'GateTokenGTBuy', '$21.89', '0.02%', '1.14%', '3.68%', '$2.69B$2,690,534,477', '$14,674,178671.03K GT', '122.91M GT']
# ['46', 'EthenaENABuy', '$0.4479', '3.07%', '17.38%', '69.55%', '$2.61B$2,607,421,841', '$474,073,3181.05B ENA', '5.82B ENA']
# ['47', 'ArbitrumARBBuy', '$0.4593', '2.65%', '7.67%', '50.81%', '$2.18B$2,184,962,838', '$327,346,116711.25M ARB', '4.75B ARB']
# ['48', 'FilecoinFILBuy', '$3.22', '1.01%', '4.34%', '25.79%', '$2.15B$2,148,068,427', '$170,876,56353.18M FIL', '665.93M FIL']
# ['49', 'AlgorandALGOBuy', '$0.2498', '1.20%', '5.46%', '27.13%', '$2.15B$2,149,031,733', '$113,429,830456.05M ALGO', '8.59B ALGO']
# ['50', 'Artificial Superintelligence AllianceFETBuy', '$0.8877', '3.28%', '7.51%', '33.86%', '$2.12B$2,122,549,142', '$181,097,060202.80M FET', '2.39B FET']
# ['51', 'World Liberty Financial USDUSD1Buy', '$1.00', '0.01%', '0.56%', '0.06%', '$2.13B$2,130,714,212', '$77,750,05377.63M USD1', '2.12B USD1']
# ['52', 'CelestiaTIABuy', '$3.34', '0.91%', '6.38%', '40.63%', '$2.12B$2,118,700,892', '$140,587,99341.85M TIA', '633.81M TIA']
# ['53', 'CosmosATOMBuy', '$5.34', '1.58%', '2.25%', '31.16%', '$2.09B$2,087,665,962', '$127,435,03123.92M ATOM', '390.93M ATOM']
# ['54', 'WorldcoinWLDBuy', '$1.32', '0.97%', '6.16%', '46.66%', '$1.94B$1,936,000,117', '$269,313,925203.77M WLD', '1.46B WLD']
# ['55', 'BonkBONKBuy', '$0.00002361', '2.31%', '6.62%', '41.98%', '$1.87B$1,869,305,112', '$670,115,51228.45T BONK', '79.17T BONK']
# ['56', 'Sonic (prev. FTM)SBuy', '$0.6155', '2.10%', '5.86%', '22.31%', '$1.77B$1,772,927,569', '$150,603,166246.06M S', '2.88B S']
# ['57', 'JupiterJUPBuy', '$0.5826', '2.26%', '7.72%', '39.84%', '$1.69B$1,688,317,880', '$69,629,205119.88M JUP', '2.89B JUP']
# ['58', 'MakerMKRBuy', '$1,894.21', '2.85%', '6.38%', '28.33%', '$1.58B$1,577,576,650', '$58,998,08431.28K MKR', '832.83K MKR']
# ['59', 'StacksSTXBuy', '$1.01', '1.53%', '5.56%', '32.70%', '$1.55B$1,549,927,235', '$61,743,12261.01M STX', '1.52B STX']
# ['60', 'First Digital USDFDUSDBuy', '$0.9989', '0.00%', '0.06%', '0.03%', '$1.51B$1,514,939,545', '$3,536,860,4803.54B FDUSD', '1.51B FDUSD']
# ['61', 'OptimismOPBuy', '$0.8900', '2.30%', '7.65%', '46.15%', '$1.47B$1,474,915,584', '$318,654,317359.06M OP', '1.65B OP']
# ['62', 'KuCoin TokenKCSBuy', '$11.40', '0.41%', '1.25%', '6.24%', '$1.43B$1,426,365,972', '$1,104,27997.02K KCS', '125.02M KCS']
# ['63', 'FartcoinFARTCOINBuy', '$1.41', '2.99%', '4.63%', '31.40%', '$1.42B$1,417,983,277', '$298,313,543211.15M FARTCOIN', '999.99M FARTCOIN']
# ['64', 'EOSEOSBuy', '$0.8955', '0.78%', '2.06%', '30.21%', '$1.4B$1,401,409,913', '$167,292,326186.95M EOS', '1.56B EOS']
# ['65', 'Virtuals ProtocolVIRTUALBuy', '$2.12', '2.18%', '10.77%', '44.63%', '$1.38B$1,384,604,432', '$389,969,532182.82M VIRTUAL', '652.59M VIRTUAL']
# ['66', 'InjectiveINJBuy', '$13.95', '2.86%', '3.26%', '51.52%', '$1.4B$1,395,571,582', '$158,526,79511.39M INJ', '99.97M INJ']
# ['67', 'ImmutableIMXBuy', '$0.7573', '3.08%', '8.01%', '43.48%', '$1.38B$1,376,304,541', '$61,651,94681.82M IMX', '1.81B IMX']
# ['68', 'SeiSEIBuy', '$0.2678', '1.68%', '5.05%', '36.60%', '$1.37B$1,368,111,109', '$101,282,866378.89M SEI', '5.1B SEI']
# ['69', 'StoryIPBuy', '$4.82', '1.16%', '4.69%', '36.77%', '$1.35B$1,347,944,512', '$76,948,09715.94M IP', '279.09M IP']
# ['70', 'FlareFLRBuy', '$0.02018', '0.60%', '2.95%', '9.06%', '$1.31B$1,314,743,168', '$8,325,332413.76M FLR', '65.12B FLR']
# ['71', 'The GraphGRTBuy', '$0.1267', '2.47%', '9.71%', '42.94%', '$1.25B$1,245,052,954', '$65,516,063517.27M GRT', '9.82B GRT']
# ['72', 'QuantQNTBuy', '$100.15', '1.50%', '4.46%', '16.90%', '$1.21B$1,209,117,655', '$26,708,995267.19K QNT', '12.07M QNT']
# ['73', 'XDC NetworkXDCBuy', '$0.07544', '0.78%', '1.59%', '5.98%', '$1.19B$1,185,110,179', '$38,831,694514.76M XDC', '15.7B XDC']
# ['74', 'dogwifhatWIFBuy', '$1.17', '2.33%', '4.91%', '116.23%', '$1.17B$1,172,003,034', '$844,260,308725.06M WIF', '998.84M WIF']
# ['75', 'FLOKIFLOKIBuy', '$0.0001184', '0.41%', '8.39%', '57.98%', '$1.14B$1,140,182,679', '$239,765,7832.01T FLOKI', '9.62T FLOKI']
# ['76', 'DeXeDEXEBuy', '$12.91', '1.86%', '0.03%', '14.44%', '$1.08B$1,081,034,630', '$24,316,9651.89M DEXE', '83.73M DEXE']
# ['77', 'Theta NetworkTHETABuy', '$1.06', '2.59%', '6.91%', '54.49%', '$1.06B$1,064,563,707', '$42,037,92539.71M THETA', '1B THETA']
# ['78', 'Curve DAO TokenCRVBuy', '$0.7839', '2.04%', '4.52%', '19.74%', '$1.05B$1,053,198,173', '$157,257,089201.56M CRV', '1.34B CRV']
# ['79', 'Lido DAOLDOBuy', '$1.16', '2.52%', '9.23%', '52.71%', '$1.04B$1,044,719,257', '$117,823,611101.57M LDO', '897.84M LDO']
# ['80', 'FourFORMBuy', '$2.68', '1.28%', '4.69%', '8.92%', '$1.03B$1,026,706,644', '$43,073,29016.05M FORM', '381.86M FORM']
# ['81', 'JasmyCoinJASMYBuy', '$0.02079', '2.27%', '4.91%', '39.00%', '$1.03B$1,028,433,445', '$85,483,0414.13B JASMY', '49.44B JASMY']
# ['82', 'GalaGALABuy', '$0.02292', '2.24%', '4.67%', '53.85%', '$1.02B$1,017,590,677', '$122,200,8695.34B GALA', '44.39B GALA']
# ['83', 'RaydiumRAYBuy', '$3.37', '2.61%', '14.71%', '43.21%', '$978.43M$978,431,084', '$117,997,19035.30M RAY', '290.28M RAY']
# ['84', 'IOTAIOTABuy', '$0.2556', '2.39%', '7.67%', '31.38%', '$959.33M$959,332,113', '$33,832,325132.51M IOTA', '3.75B IOTA']
# ['85', 'The SandboxSANDBuy', '$0.3664', '1.04%', '3.79%', '36.73%', '$930.04M$930,036,685', '$109,192,465298.01M SAND', '2.53B SAND']
# ['86', 'Pudgy PenguinsPENGUBuy', '$0.01462', '2.50%', '11.12%', '31.06%', '$919.12M$919,120,500', '$273,573,55918.60B PENGU', '62.86B PENGU']
# ['87', 'Ethereum Name ServiceENSBuy', '$24.83', '2.11%', '9.61%', '43.34%', '$901.24M$901,244,287', '$141,824,4205.73M ENS', '36.29M ENS']
# ['88', 'WalrusWALBuy', '$0.6703', '1.88%', '4.68%', '21.52%', '$881.75M$881,753,554', '$50,012,62675.05M WAL', '1.31B WAL']
# ['89', 'CoreCOREBuy', '$0.8588', '1.77%', '2.05%', '19.64%', '$859.82M$859,821,352', '$26,774,89231.24M CORE', '1B CORE']
# ['90', 'PayPal USDPYUSDBuy', '$0.9998', '0.02%', '0.03%', '0.04%', '$838.08M$838,083,890', '$20,600,35420.60M PYUSD', '838.21M PYUSD']
# ['91', 'NexoNEXOBuy', '$1.29', '0.62%', '2.80%', '4.10%', '$836.88M$836,875,398', '$12,481,2789.66M NEXO', '646.14M NEXO']
# ['92', 'Brett (Based)BRETTBuy', '$0.08428', '3.32%', '12.03%', '70.88%', '$835.28M$835,283,143', '$50,662,191606.19M BRETT', '9.91B BRETT']
# ['93', 'BitTorrent [New]BTTBuy', '$0.068290', '1.41%', '2.67%', '19.78%', '$817.51M$817,511,052', '$32,625,18739.40T BTT', '986.06T BTT']
# ['94', 'Bitcoin SVBSVBuy', '$40.95', '1.39%', '3.79%', '14.25%', '$813.53M$813,532,052', '$68,943,2791.68M BSV', '19.86M BSV']
# ['95', 'Tether GoldXAUtBuy', '$3,250.82', '0.05%', '0.33%', '5.06%', '$801.41M$801,406,410', '$22,901,2217.04K XAUt', '246.52K XAUt']
# ['96', 'PancakeSwapCAKEBuy', '$2.47', '1.42%', '4.93%', '24.63%', '$794.15M$794,149,500', '$102,151,95641.25M CAKE', '320.74M CAKE']
# ['97', 'SPX6900SPXBuy', '$0.8496', '3.41%', '13.83%', '70.56%', '$791.04M$791,036,217', '$35,392,94642.06M SPX', '930.99M SPX']
# ['98', 'KaiaKAIABuy', '$0.1294', '0.49%', '1.89%', '19.81%', '$779.04M$779,035,817', '$23,528,433181.78M KAIA', '6.01B KAIA']
# ['99', 'PAX GoldPAXGBuy', '$3,260.40', '0.03%', '0.32%', '4.87%', '$772.45M$772,445,609', '$45,307,63013.89K PAXG', '236.91K PAXG']
# ['100', 'FlowFLOWBuy', '$0.4715', '1.49%', '5.30%', '28.85%', '$745.73M$745,733,558', '$40,545,52086.01M FLOW', '1.58B FLOW']
